# %%
# ingest the data

import pandas as pd

# %%
gemstone = pd.read_csv(r"/Users/smandapati/Desktop/Shanmukh/FSDSMendtoend/notebooks/gemstone.csv")

# %%
gemstone.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
gemstone.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
gemstone.sample(5)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 60809    60809   1.50    Premium     D     VS2   62.7   59.0  7.27  7.30
# 168118  168118   0.72    Premium     F     SI1   62.8   59.0  5.69  5.67
# 159767  159767   0.53      Ideal     G     VS2   60.7   55.0  5.28  5.23
# 103993  103993   1.04  Very Good     F     VS2   63.2   55.0  6.42  6.45
# 150077  150077   0.35      Ideal     F     VS2   62.3   55.0  4.55  4.52
#
#            z  price
# 60809   4.58  15888
# 168118  3.56   2458
# 159767  3.20   1415
# 103993  4.06   6701
# 150077  2.82   1013

# %%
gemstone.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
gemstone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
gemstone.drop(labels=["id"],axis=1)
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]

# %%
gemstone.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
gemstone.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 193568    False
# 193569    False
# 193570    False
# 193571    False
# 193572    False
# Length: 193573, dtype: bool

# %%
gemstone.duplicated().sum()
# Out:
# 0

# %%
gemstone.shape
# Out:
# (193573, 11)

# %%
cat_columns=gemstone.columns[gemstone.dtypes=="object"]

# %%
numerical_columns=gemstone.columns[gemstone.dtypes!="object"]

# %%
gemstone[cat_columns]
# Out:
#               cut color clarity
# 0         Premium     F     VS2
# 1       Very Good     J     SI2
# 2           Ideal     G     VS1
# 3           Ideal     G     VS1
# 4         Premium     G     VS2
# ...           ...   ...     ...
# 193568      Ideal     D    VVS2
# 193569    Premium     G    VVS2
# 193570  Very Good     F     SI1
# 193571  Very Good     D     SI1
# 193572       Good     E     SI2
#
# [193573 rows x 3 columns]

# %%
gemstone[numerical_columns]
# Out:
#             id  carat  depth  table     x     y     z  price
# 0            0   1.52   62.2   58.0  7.27  7.33  4.55  13619
# 1            1   2.03   62.0   58.0  8.06  8.12  5.05  13387
# 2            2   0.70   61.2   57.0  5.69  5.73  3.50   2772
# 3            3   0.32   61.6   56.0  4.38  4.41  2.71    666
# 4            4   1.70   62.6   59.0  7.65  7.61  4.77  14453
# ...        ...    ...    ...    ...   ...   ...   ...    ...
# 193568  193568   0.31   61.1   56.0  4.35  4.39  2.67   1130
# 193569  193569   0.70   60.3   58.0  5.75  5.77  3.47   2874
# 193570  193570   0.73   63.1   57.0  5.72  5.75  3.62   3036
# 193571  193571   0.34   62.9   55.0  4.45  4.49  2.81    681
# 193572  193572   0.71   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 8 columns]

# %%
gemstone[cat_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
gemstone[cat_columns]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
gemstone[cat_columns]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
gemstone[cat_columns]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
gemstone[numerical_columns].describe().T
# Out:
#           count          mean           std    min       25%       50%  \
# id     193573.0  96786.000000  55879.856166    0.0  48393.00  96786.00
# carat  193573.0      0.790688      0.462688    0.2      0.40      0.70
# depth  193573.0     61.820574      1.081704   52.1     61.30     61.90
# table  193573.0     57.227675      1.918844   49.0     56.00     57.00
# x      193573.0      5.715312      1.109422    0.0      4.70      5.70
# y      193573.0      5.720094      1.102333    0.0      4.71      5.72
# z      193573.0      3.534246      0.688922    0.0      2.90      3.53
# price  193573.0   3969.155414   4034.374138  326.0    951.00   2401.00
#
#              75%        max
# id     145179.00  193572.00
# carat       1.03       3.50
# depth      62.40      71.60
# table      58.00      79.00
# x           6.51       9.65
# y           6.51      10.01
# z           4.03      31.30
# price    5408.00   18818.00
